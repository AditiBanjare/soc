# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import pyplot
import seaborn as sns
import math
from math import sqrt
from sklearn.metrics import mean_squared_error,mean_absolute_error
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.arima.model import ARIMA
# !pip install pmdarima
from pmdarima import auto_arima
from pandas import DataFrame
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf
# Out:
# Requirement already satisfied: pmdarima in /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages (1.8.5)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (0.13.2)
# Requirement already satisfied: urllib3 in /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.26.9)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (0.29.28)
# Requirement already satisfied: numpy>=1.19.3 in /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.21.5)
# Requirement already satisfied: scipy>=1.3.2 in /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.1.0)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.0.2)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (61.2.0)
# Requirement already satisfied: pandas>=0.19 in /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages (from pmdarima) (1.4.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.19->pmdarima) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.19->pmdarima) (2021.3)
# Requirement already satisfied: six>=1.5 in /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.8.1->pandas>=0.19->pmdarima) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages (from scikit-learn>=0.22->pmdarima) (2.2.0)
# Requirement already satisfied: packaging>=21.3 in /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (21.3)
# Requirement already satisfied: patsy>=0.5.2 in /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.2)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages (from packaging>=21.3->statsmodels!=0.12.0,>=0.11->pmdarima) (3.0.4)

# %%
# df here is the HDFC_6m dataset
# I will be working on this dataset for the entire predictions

df = pd.read_csv(r"/Users/aditibanjare/Downloads/HDFCBANK.NS(6).csv")
df
# Out:
#            Date         Open         High          Low        Close  \
# 0    2022-01-20  1528.449951  1528.500000  1500.099976  1509.000000
# 1    2022-01-21  1500.000000  1529.800049  1485.599976  1521.599976
# 2    2022-01-24  1509.949951  1521.250000  1467.550049  1486.650024
# 3    2022-01-25  1458.650024  1495.000000  1444.000000  1488.050049
# 4    2022-01-27  1450.000000  1485.000000  1435.000000  1474.949951
# ..          ...          ...          ...          ...          ...
# 118  2022-07-13  1390.000000  1394.199951  1354.250000  1357.849976
# 119  2022-07-14  1362.000000  1372.650024  1349.250000  1351.050049
# 120  2022-07-15  1353.000000  1364.900024  1346.800049  1362.050049
# 121  2022-07-18  1348.000000  1366.099976  1342.050049  1347.550049
# 122  2022-07-19  1337.000000  1358.550049  1337.000000  1348.050049
#
#        Adj Close    Volume
# 0    1491.656494   7598923
# 1    1504.111694   5768847
# 2    1469.563354   5934254
# 3    1470.947266   6797124
# 4    1457.997803  14308919
# ..           ...       ...
# 118  1357.849976   7972805
# 119  1351.050049   5186205
# 120  1362.050049   6797823
# 121  1347.550049  10166110
# 122  1348.050049   7896269
#
# [123 rows x 7 columns]

# %% [markdown]
# I will firstly list down the steps that I am going to follow -
#
# 1. Exploratory Data Analysis - This involves -
#    1. Redundant data removal
#    2. Conversion of ‘Date’ Attribute to dateTime and
#    3. Use of the grouping function to group ‘Date’ and ‘Close’
# 2. Stationarity Test
#    1. ACF and PACF plots
#    2. Dicky Fuller Test
# 3. Auto ARIMA
#    1. Computing Optimum values of p,d and q
# 4. Building the model

# %%
# checking for null values in df dataset

df.isnull().sum()
# Out:
# Date         0
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# dtype: int64

# %%
# since there are no null values in the df data set we can move forward

# %%
# Conversion of ‘Date’ Attribute to dateTime for df dataset
# This makes the dataet compatible of ARIMA model

type(df.Date[0])
# Out:
# str

# %%
df["Date"] = pd.to_datetime(df["Date"], format = '%Y-%m-%d')

# %%
type(df.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
# Use of the grouping function to group ‘Date’ and ‘Close’
# Used to group only the relevant attributes from the dataset

df_new = df.groupby('Date')[['Close']].mean()
df_new
# Out:
#                   Close
# Date
# 2022-01-20  1509.000000
# 2022-01-21  1521.599976
# 2022-01-24  1486.650024
# 2022-01-25  1488.050049
# 2022-01-27  1474.949951
# ...                 ...
# 2022-07-13  1357.849976
# 2022-07-14  1351.050049
# 2022-07-15  1362.050049
# 2022-07-18  1347.550049
# 2022-07-19  1348.050049
#
# [123 rows x 1 columns]

# %%
# ACF and PACF plots
# A data is said to be stationary if the mean, variance and autocorrelation structure do not show any difference over time

# %%
plot_acf(df_new['Close'])
pyplot.show()

# %%
plot_pacf(df_new['Close'], lags = 50)
pyplot.show()
# Out:
# /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages/statsmodels/graphics/tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
# Dicky Fuller Test
# For a dataset to be stationary, p-value must be less than 5%
# We assume that it is not so

# %%
result = adfuller(df_new['Close'])
print(result)
print('ADF Statistic: %f' % result[0])
print('p-value: %f' % result[1])
print('#Lags Used : %f'% result[2])
print('Number of Observation Used: %f' % (result[3]))
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# (-2.4338817667127874, 0.13240094754288856, 1, 121, {'1%': -3.485585145896754, '5%': -2.885738566292665, '10%': -2.5796759080663887}, 1037.460668494948)
# ADF Statistic: -2.433882
# p-value: 0.132401
# #Lags Used : 1.000000
# Number of Observation Used: 121.000000
# Critical Values:
# 	1%: -3.486
# 	5%: -2.886
# 	10%: -2.580

# %%
df_new['Close First Difference'] = df_new['Close'] - df_new['Close'].shift(1)
df_new['Close'].shift(1)
# Out:
# Date
# 2022-01-20            NaN
# 2022-01-21    1509.000000
# 2022-01-24    1521.599976
# 2022-01-25    1486.650024
# 2022-01-27    1488.050049
#                  ...
# 2022-07-13    1391.800049
# 2022-07-14    1357.849976
# 2022-07-15    1351.050049
# 2022-07-18    1362.050049
# 2022-07-19    1347.550049
# Name: Close, Length: 123, dtype: float64

# %%
result1 = adfuller(df_new['Close First Difference'].dropna())
print(result1)
print('ADF Statistic: %f' % result1[0])
print('p-value: %f' % result1[1])
print('#Lags Used : %f'% result1[2])
print('Number of Observation Used: %f' % (result1[3]))
print('Critical Values:')
for key, value in result[4].items():
	print('\t%s: %.3f' % (key, value))
# Out:
# (-10.038257989233212, 1.5202337664458792e-17, 0, 121, {'1%': -3.485585145896754, '5%': -2.885738566292665, '10%': -2.5796759080663887}, 1032.0100113659519)
# ADF Statistic: -10.038258
# p-value: 0.000000
# #Lags Used : 0.000000
# Number of Observation Used: 121.000000
# Critical Values:
# 	1%: -3.486
# 	5%: -2.886
# 	10%: -2.580

# %%
adfuller(df_new['Close First Difference'].dropna())
df_new['Close First Difference'].plot(figsize = (12,8))
plt.xlabel("Year")
plt.ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
# After the above steps the dataset has become stationary, so we move forward 
# Auto ARIMA, Computing Optimum values of p,d and q for the best results of forecasting for the ARIMA model.
# Model whose AIC value is the lowest

# %%
stepwise_fit = auto_arima(df_new['Close'],trace = True, suppress_warnings = True)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=1166.935, Time=0.27 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=1163.597, Time=0.01 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=1164.735, Time=0.05 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=1164.472, Time=0.04 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=1161.866, Time=0.01 sec
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=1165.755, Time=0.05 sec
#
# Best model:  ARIMA(0,1,0)(0,0,0)[0]
# Total fit time: 0.458 seconds
# /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1
# /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1899: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ar)**-1
# /Users/aditibanjare/opt/anaconda3/lib/python3.9/site-packages/statsmodels/tsa/statespace/sarimax.py:1906: RuntimeWarning: invalid value encountered in reciprocal
#   return np.roots(self.polynomial_reduced_ma)**-1

# %%
print(stepwise_fit.summary())
stepwise_fit.plot_diagnostics(figsize = (15,8))
plt.show()
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  123
# Model:               SARIMAX(0, 1, 0)   Log Likelihood                -579.933
# Date:                Thu, 28 Jul 2022   AIC                           1161.866
# Time:                        22:40:43   BIC                           1164.670
# Sample:                             0   HQIC                          1163.005
#                                 - 123
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2       787.7961     50.414     15.626      0.000     688.986     886.606
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.88   Jarque-Bera (JB):               207.83
# Prob(Q):                              0.35   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.30   Skew:                             0.81
# Prob(H) (two-sided):                  0.00   Kurtosis:                         9.19
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# 1. Top left - Uniform variance and fluctuates around a mean of zero
#
# 2. Top Right - Normal distribution with a mean of zero
#
# 3. Bottom left - Significant deviations indicate a skewed distribution
#
# 4. Bottom Right - The residual errors are not autocorrelated

# %%
# Now comes the final part of Building the model

# %%
series = df_new['Close']
x = series.values
size = int(len(x) * 0.7)
train, test = x[0:size], x[size:len(x)] 
model = ARIMA(train, order=(0, 1, 0))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                   86
# Model:                 ARIMA(0, 1, 0)   Log Likelihood                -415.860
# Date:                Thu, 28 Jul 2022   AIC                            833.721
# Time:                        22:40:49   BIC                            836.164
# Sample:                             0   HQIC                           834.703
#                                  - 86
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2      1040.1158     89.439     11.629      0.000     864.819    1215.412
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.37   Jarque-Bera (JB):                80.61
# Prob(Q):                              0.54   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.62   Skew:                             0.77
# Prob(H) (two-sided):                  0.21   Kurtosis:                         7.51
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(series)
plt.figure(figsize=(10, 7), dpi=80)
plt.show()

# %%
# testing of the model

# %%
history = [i for i in train]
predictions = list()
for t in range(len(test)):
    model = ARIMA(history, order=(0,1,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test[t]
    history.append(obs)

print(predictions)
# Out:
# [1392.050049, 1401.550049, 1388.949951, 1394.849976, 1385.099976, 1380.300049, 1378.449951, 1362.599976, 1367.400024, 1377.699951, 1351.099976, 1326.599976, 1312.0, 1307.449951, 1281.300049, 1289.75, 1322.150024, 1336.550049, 1330.25, 1335.150024, 1353.800049, 1356.25, 1345.900024, 1343.949951, 1348.0, 1353.75, 1355.650024, 1352.599976, 1371.25, 1395.800049, 1397.099976, 1406.150024, 1391.800049, 1357.849976, 1351.050049, 1362.050049, 1347.550049]

# %%
# model performance test

# %%
mse = mean_squared_error(test, predictions)
print('MSE: '+str(mse))
mae = mean_absolute_error(test, predictions)
print('MAE: '+str(mae))
rmse = math.sqrt(mean_squared_error(test, predictions))
print('RMSE: '+str(rmse))
mape = np.mean(np.abs(predictions - test)/np.abs(test))
print('MAPE: '+str(mape))
# Out:
# MSE: 208.13323427268423
# MAE: 11.37838491891892
# RMSE: 14.426823429732694
# MAPE: 0.008424555215530719

# %%
# Plotting the predicted prices from ARIMA model and real prices

# %%
plt.figure(figsize=(12, 6), dpi=100)
plt.plot(test, color='blue', label='Real')
plt.plot(predictions, color='red', label='Predicted')
plt.xlabel('Days')
plt.ylabel('USD')
plt.title('Figure : ARIMA model on MSFT stock')
plt.legend()
plt.show()

# %%
# future predictions

# %%
pred = model_fit.predict(start = len(df_new), end = len(df_new)+30, typ = 'levels')
print(pred)
# Out:
# [1347.550049 1347.550049 1347.550049 1347.550049 1347.550049 1347.550049
#  1347.550049 1347.550049 1347.550049 1347.550049 1347.550049 1347.550049
#  1347.550049 1347.550049 1347.550049 1347.550049 1347.550049 1347.550049
#  1347.550049 1347.550049 1347.550049 1347.550049 1347.550049 1347.550049
#  1347.550049 1347.550049 1347.550049 1347.550049 1347.550049 1347.550049
#  1347.550049]
